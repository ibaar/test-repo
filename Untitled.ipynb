# %%
x = [x for x in range(0,10)]
lin = [x for x in range(0,10)]
quad= [x**2 for x in range(0,10)]
cubic = [x**3 for x in range(0,10)]
expo = [1.5**x for x in range(0,10)]

# %%
import pylab as plt

# %%
pylab.figure('lib')
pylab.plot(x,lin)
pylab.figure('quad')
pylab.plot(x,quad)
pylab.figure('cubic')
pylab.plot(x,cubic)
pylab.figure('expo')
pylab.plot(x,expo)
